# %%
conda install matplotlib
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/homebrew/Caskroom/miniforge/base
#
#   added / updated specs:
#     - matplotlib
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     conda-4.11.0               |   py39hca03da5_0        14.4 MB
#     ------------------------------------------------------------
#                                            Total:        14.4 MB
#
# The following NEW packages will be INSTALLED:
#
#   brotli             pkgs/main/osx-arm64::brotli-1.0.7-hc377ac9_0
#   cycler             pkgs/main/noarch::cycler-0.11.0-pyhd3eb1b0_0
#   fonttools          pkgs/main/noarch::fonttools-4.25.0-pyhd3eb1b0_0
#   freetype           pkgs/main/osx-arm64::freetype-2.11.0-h1192e45_0
#   giflib             pkgs/main/osx-arm64::giflib-5.2.1-h1a28f6b_0
#   jpeg               pkgs/main/osx-arm64::jpeg-9d-h1a28f6b_0
#   kiwisolver         pkgs/main/osx-arm64::kiwisolver-1.3.1-py39hc377ac9_0
#   lcms2              pkgs/main/osx-arm64::lcms2-2.12-hba8e193_0
#   libpng             pkgs/main/osx-arm64::libpng-1.6.37-hb8d0fd4_0
#   libtiff            pkgs/main/osx-arm64::libtiff-4.2.0-h11e2f9f_0
#   libwebp            pkgs/main/osx-arm64::libwebp-1.2.0-h68602c7_0
#   libwebp-base       pkgs/main/osx-arm64::libwebp-base-1.2.0-h1a28f6b_0
#   lz4-c              pkgs/main/osx-arm64::lz4-c-1.9.3-hc377ac9_0
#   matplotlib         pkgs/main/osx-arm64::matplotlib-3.5.0-py39hca03da5_0
#   matplotlib-base    pkgs/main/osx-arm64::matplotlib-base-3.5.0-py39h9197a36_0
#   munkres            pkgs/main/noarch::munkres-1.1.4-py_0
#   olefile            pkgs/main/noarch::olefile-0.46-pyhd3eb1b0_0
#   pillow             pkgs/main/osx-arm64::pillow-8.3.1-py39hf1d1977_0
#   zstd               pkgs/main/osx-arm64::zstd-1.4.9-h8574219_1
#
# The following packages will be UPDATED:
#
#   ca-certificates    conda-forge::ca-certificates-2021.10.~ --> pkgs/main::ca-certificates-2021.10.26-hca03da5_2
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   certifi            conda-forge::certifi-2021.10.8-py39h2~ --> pkgs/main::certifi-2021.5.30-py39hca03da5_1
#   conda              conda-forge::conda-4.11.0-py39h2804cb~ --> pkgs/main::conda-4.11.0-py39hca03da5_0
#
#
#
# Downloading and Extracting Packages
# conda-4.11.0         | 14.4 MB   | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import matplotlib.pyplot as plt


resnet_34_top1_err = np.array([0.067, 0.1204, 0.1948, 0.5801, 0.8990])
resnet_18_top1_err = np.array([0.0693, 0.1205, 0.2322, 0.3940, 0.8777])
vgg_16_top1_err = np.array([0.0600, 0.1179, 0.2236, 0.3754, 0.8334])
resnet_34_top5_err = np.array([0.0025, 0.0070, 0.0235, 0.1098, 0.4097])
resnet_18_top5_err = np.array([0.0026, 0.0057, 0.0221, 0.0948, 0.3096])
vgg_16_top5_err = np.array([0.0036, 0.0100, 0.0431, 0.0729, 0.3460])


resnet_34_top1_acc = np.array([0.0099, 0.0514, 0.8373, 0.9999])
resnet_18_top1_acc = np.array([0.0089, 0.1004, 0.5969, 0.9915])
vgg_16_top1_acc = np.array([0.0088, 0.0570, 0.1098, 0.9611])
resnet_34_top5_acc = np.array([0.1927, 0.4734, 0.9885, 1.0000])
resnet_18_top5_acc = np.array([0.2411, 0.6690, 0.9275, 1.0000])
vgg_16_top5_acc = np.array([0.3189, 0.5008, 0.3575, 0.9972])

patch_sizes = np.array([2,4,8,16])
patch_size_err = np.array([0,2,4,8,16])


plt.figure(1,figsize=(8,8))
plt.clf()
plt.plot(patch_size_err, resnet_34_top1_err, label = "Baseline ResNet-34 Top 1")
plt.plot(patch_size_err, resnet_18_top1_err, label = "ResNet-18 Top 1")
plt.plot(patch_size_err, vgg_16_top1_err, label = "VGG-16 Top 1")

plt.plot(patch_size_err, resnet_34_top5_err, label = "Baseline ResNet-34 Top 5", ls="--")
plt.plot(patch_size_err, resnet_18_top5_err, label = "ResNet-18 Top 5",ls="--")
plt.plot(patch_size_err, vgg_16_top5_err, label = "VGG-16 Top 5",ls="--")

plt.xlabel('Patch Size', size = 20)
plt.ylabel('Error', size = 20)
plt.title('Top 1 and Top 5 Error for Different Models', size = 22)
plt.legend()
plt.show()

plt.figure(2,figsize=(8,8))
plt.clf()
plt.plot(patch_sizes, resnet_34_top1_acc, label = "Baseline ResNet-34 Top 1")
plt.plot(patch_sizes, resnet_18_top1_acc, label = "ResNet-18 Top 1")
plt.plot(patch_sizes, vgg_16_top1_acc, label = "VGG-16 Top 1")

plt.plot(patch_sizes, resnet_34_top5_acc, label = "Baseline ResNet-34 Top 5",ls="--")
plt.plot(patch_sizes, resnet_18_top5_acc, label = "ResNet-18 Top 5",ls="--")
plt.plot(patch_sizes, vgg_16_top5_acc, label = "VGG-16 Top 5",ls="--")

plt.xlabel('Patch Size', size = 20)
plt.ylabel('Misled Accuracy', size = 20)
plt.title('Top 1 and Top 5 Accuracy for Different Models', size = 22)
plt.legend()
plt.show()
